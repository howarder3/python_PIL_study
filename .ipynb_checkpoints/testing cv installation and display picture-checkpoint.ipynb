# %%
import sys
print("python版本:%s"% sys.version)

import cv2
print("opencv版本:%s"% cv2.__version__)
# Out:
# python版本:3.6.3 |Anaconda, Inc.| (default, Nov  8 2017, 15:10:56) [MSC v.1900 64 bit (AMD64)]
# opencv版本:4.1.0

# %% [markdown]
# ### debug
# https://stackoverflow.com/questions/20518632/importerror-numpy-core-multiarray-failed-to-import
#
# ### my mote
# https://hackmd.io/dIiE8-ReQY-GCs1zdqn3WQ?both
#
# ### show picture
# https://stackoverflow.com/questions/11854847/how-can-i-display-an-image-from-a-file-in-jupyter-notebook
#
# ### install
# https://juejin.im/post/596b3e50f265da6c2211b609

# %%
import cv2

img = cv2.imread("1.jpg", 0)
width = img.shape[1]
heigt = img.shape[0]
mean = cv2.mean(img)[0]
# print("".format(img))
print("img_shape = {}".format(img.shape))
print("mean = {}".format(mean))
(mean , stddv) = cv2.meanStdDev(img)
print("mean = {}".format(mean))
print("stddv = {}".format(stddv))


from IPython.display import Image
Image(filename='1.jpg')
# Out:
# img_shape = (256, 256)
# mean = 79.34080505371094
# mean = [[79.34080505]]
# stddv = [[35.45588525]]

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import urllib.request as ul

data = None

try:

    data = 

except Exception as e:

    print("Could not download the image: %s " %( e.message))

else:
    data =  np.fromstring(data, np.uint8)
    img_data =  cv2.imdecode(data, cv2.IMREAD_COLOR )
    img_data = cv2.cvtColor(img_data, cv2.COLOR_BGR2RGB)
    plt.imshow(img_data)
    plt.show()
